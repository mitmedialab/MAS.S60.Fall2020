# %% [markdown]
# # HW0 - Warmup
#
# In this assignment we will warmup our coding skills and have a short intro to machine learning mechanics.
#
# Readings:
# - AI creativity: https://towardsdatascience.com/supercreativity-b4114ebd0357
# - Generative Models: https://openai.com/blog/generative-models/
# - ML intro http://www.r2d3.us/visual-intro-to-machine-learning-part-1/
# - NN activations: https://distill.pub/2019/activation-atlas/
#
# We will see three cool tricks with neural networks that show their generative power:
# - Style Transfer
# - Deep Dream
# - Neural Doodle
#
# These are "old" tricks, but they can still teach us a whole lot about how neural networks work and what they can be used for. Some key concepts to look out for are: **Loss function, Gradient (descent), Activation, Layer**.
#
# You are welcome to tweak parameters and see what results you get!
# But it will be the best if you actually hack around and change input images...
#
# BTW: All this code is free for you (and everyone) to use and share!

# %% [markdown]
# <div class="alert alert-block alert-info" style="text-align: center;">
# <a href="https://colab.research.google.com/github/mitmedialab/MAS.S60.Fall2020/blob/master/homework/HW0%20-%20Warmup.ipynb"><img src="https://www.tensorflow.org/images/colab_logo_32px.png" /> Run in Google Colab</a>
# </div>

# %%
# There's some boilerplate code here below, run it (shift+Enter over each cell) ... Expand and take a peek if you'd like

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from __future__ import absolute_import, division, print_function

import functools
import os
import time

import matplotlib.pylab as plt
import numpy as np
import tensorflow as tf
import tensorflow_hub as hub
from IPython.display import clear_output

print("TF Version: ", tf.__version__)
print("TF-Hub version: ", hub.__version__)
print("Eager mode enabled: ", tf.executing_eagerly())
print("GPU available: ", tf.test.is_gpu_available())
# Out:
# TF Version:  2.3.0
# TF-Hub version:  0.9.0
# Eager mode enabled:  True
# WARNING:tensorflow:From <ipython-input-4-9d7a6973bc01>:16: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU available:  True

# %%
def load_image(image_url, image_size=(256, 256), preserve_aspect_ratio=True):
    """Loads and preprocesses images."""
    # Cache image file locally.
    image_path = tf.keras.utils.get_file(os.path.basename(image_url)[-128:], image_url)
    # Load and convert to float32 numpy array, add batch dimension, and normalize to range [0, 1].
    img = plt.imread(image_path).astype(np.float32)[np.newaxis, ...] / 255.
    if img.shape[-1] == 4:
        img = img[..., :3] / tf.expand_dims(img[..., 3], -1) # pre multiply alpha
        
    img = tf.image.resize(img, image_size, preserve_aspect_ratio=True)
    return img

def show_n(images, titles=('',), w=8, colorbar=False):
    n = len(images)
    plt.figure(figsize=(w * n, w))
    for i in range(n):
        plt.subplot(1, n, 1 + i)
        plt.imshow(images[i][0], aspect='equal')
        plt.axis('off')
        plt.title(titles[i] if len(titles) > i else '')
        if colorbar:
            plt.colorbar()
    plt.show()

# %% [markdown]
# ## Style Transfer
#
# Style transfer is a neat implementation using deep convolutional networks to tranfer artistic style from one image to another.
#
# Read in more depth: https://blog.paperspace.com/art-with-neural-networks/
#
# Cool examples of style transfer: http://genekogan.com/works/style-transfer/

# %% [markdown]
# Let's load some images from the net:

# %%
content_image_url = 'https://upload.wikimedia.org/wikipedia/commons/thumb/f/fd/Golden_Gate_Bridge_from_Battery_Spencer.jpg/640px-Golden_Gate_Bridge_from_Battery_Spencer.jpg'
style_image_url = 'https://upload.wikimedia.org/wikipedia/commons/0/0a/The_Great_Wave_off_Kanagawa.jpg' 
output_image_size = 512 

# The content image size can be arbitrary.
content_img_size = (output_image_size, output_image_size)
style_img_size = (256, 256)  # Recommended to keep it at 256.

content_image = load_image(content_image_url, content_img_size)
style_image = load_image(style_image_url, style_img_size)
# Out:
# Downloading data from https://upload.wikimedia.org/wikipedia/commons/thumb/f/fd/Golden_Gate_Bridge_from_Battery_Spencer.jpg/640px-Golden_Gate_Bridge_from_Battery_Spencer.jpg
# 65536/58102 [=================================] - 0s 1us/step
# Downloading data from https://upload.wikimedia.org/wikipedia/commons/0/0a/The_Great_Wave_off_Kanagawa.jpg
# 2686976/2684586 [==============================] - 0s 0us/step

# %%
show_n([content_image, style_image], ['Content', 'Style'])

# %% [markdown]
# The goal is to apply the style of "Style Image" to "Content Image".
#
# Tensorflow Hub is a collection of models pre-trained and ready to use.
# We can find a style transfer model there too: https://tfhub.dev/google/magenta/arbitrary-image-stylization-v1-256/1

# %%
# Load image stylization module.

hub_handle = 'https://tfhub.dev/google/magenta/arbitrary-image-stylization-v1-256/2'
hub_module = hub.load(hub_handle)

# %% [markdown]
# Using it is very straightforward:

# %%
# Stylize image.
outputs = hub_module(content_image, style_image)
stylized_image = outputs[0]

# %% [markdown]
# And the reults are cool!

# %%
show_n([content_image, style_image, stylized_image], ['Content', 'Style', 'Stylized'])

# %% [markdown]
# What happens here under the hood is that we iteratively change the "Content Image" to follow the "Style Image" on "low visual layers". The deep convolutional neural network is divided to many layers (sometimes dozens and hundreds). Each layer successively learns more complex visual constructs. If we try to match just the lower layers - only the "painting style" will transfer.

# %% [markdown]
# Have a look at the list layers of the deep model below. You will see many of them belong to "**InceptionV3**", which is a very well known deep model for classification. That part is known as the "**backbone**" - it's only used to exract visual features. The other layers show many convolution layers, resudial operators, and more.

# %%
sorted([f.name for f in hub_module.variables])
# Out:
# ['InceptionV3/Conv2d_1a_3x3/BatchNorm/beta:0',
#  'InceptionV3/Conv2d_1a_3x3/BatchNorm/moving_mean:0',
#  'InceptionV3/Conv2d_1a_3x3/BatchNorm/moving_variance:0',
#  'InceptionV3/Conv2d_1a_3x3/weights:0',
#  'InceptionV3/Conv2d_2a_3x3/BatchNorm/beta:0',
#  'InceptionV3/Conv2d_2a_3x3/BatchNorm/moving_mean:0',
#  'InceptionV3/Conv2d_2a_3x3/BatchNorm/moving_variance:0',
#  'InceptionV3/Conv2d_2a_3x3/weights:0',
#  'InceptionV3/Conv2d_2b_3x3/BatchNorm/beta:0',
#  'InceptionV3/Conv2d_2b_3x3/BatchNorm/moving_mean:0',
#  'InceptionV3/Conv2d_2b_3x3/BatchNorm/moving_variance:0',
#  'InceptionV3/Conv2d_2b_3x3/weights:0',
#  'InceptionV3/Conv2d_3b_1x1/BatchNorm/beta:0',
#  'InceptionV3/Conv2d_3b_1x1/BatchNorm/moving_mean:0',
#  'InceptionV3/Conv2d_3b_1x1/BatchNorm/moving_variance:0',
#  'InceptionV3/Conv2d_3b_1x1/weights:0',
#  'InceptionV3/Conv2d_4a_3x3/BatchNorm/beta:0',
#  'InceptionV3/Conv2d_4a_3x3/BatchNorm/moving_mean:0',
#  'InceptionV3/Conv2d_4a_3x3/BatchNorm/moving_variance:0',
#  'InceptionV3/Conv2d_4a_3x3/weights:0',
#  'InceptionV3/Mixed_5b/Branch_0/Conv2d_0a_1x1/BatchNorm/beta:0',
#  'InceptionV3/Mixed_5b/Branch_0/Conv2d_0a_1x1/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_5b/Branch_0/Conv2d_0a_1x1/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_5b/Branch_0/Conv2d_0a_1x1/weights:0',
#  'InceptionV3/Mixed_5b/Branch_1/Conv2d_0a_1x1/BatchNorm/beta:0',
#  'InceptionV3/Mixed_5b/Branch_1/Conv2d_0a_1x1/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_5b/Branch_1/Conv2d_0a_1x1/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_5b/Branch_1/Conv2d_0a_1x1/weights:0',
#  'InceptionV3/Mixed_5b/Branch_1/Conv2d_0b_5x5/BatchNorm/beta:0',
#  'InceptionV3/Mixed_5b/Branch_1/Conv2d_0b_5x5/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_5b/Branch_1/Conv2d_0b_5x5/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_5b/Branch_1/Conv2d_0b_5x5/weights:0',
#  'InceptionV3/Mixed_5b/Branch_2/Conv2d_0a_1x1/BatchNorm/beta:0',
#  'InceptionV3/Mixed_5b/Branch_2/Conv2d_0a_1x1/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_5b/Branch_2/Conv2d_0a_1x1/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_5b/Branch_2/Conv2d_0a_1x1/weights:0',
#  'InceptionV3/Mixed_5b/Branch_2/Conv2d_0b_3x3/BatchNorm/beta:0',
#  'InceptionV3/Mixed_5b/Branch_2/Conv2d_0b_3x3/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_5b/Branch_2/Conv2d_0b_3x3/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_5b/Branch_2/Conv2d_0b_3x3/weights:0',
#  'InceptionV3/Mixed_5b/Branch_2/Conv2d_0c_3x3/BatchNorm/beta:0',
#  'InceptionV3/Mixed_5b/Branch_2/Conv2d_0c_3x3/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_5b/Branch_2/Conv2d_0c_3x3/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_5b/Branch_2/Conv2d_0c_3x3/weights:0',
#  'InceptionV3/Mixed_5b/Branch_3/Conv2d_0b_1x1/BatchNorm/beta:0',
#  'InceptionV3/Mixed_5b/Branch_3/Conv2d_0b_1x1/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_5b/Branch_3/Conv2d_0b_1x1/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_5b/Branch_3/Conv2d_0b_1x1/weights:0',
#  'InceptionV3/Mixed_5c/Branch_0/Conv2d_0a_1x1/BatchNorm/beta:0',
#  'InceptionV3/Mixed_5c/Branch_0/Conv2d_0a_1x1/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_5c/Branch_0/Conv2d_0a_1x1/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_5c/Branch_0/Conv2d_0a_1x1/weights:0',
#  'InceptionV3/Mixed_5c/Branch_1/Conv2d_0b_1x1/BatchNorm/beta:0',
#  'InceptionV3/Mixed_5c/Branch_1/Conv2d_0b_1x1/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_5c/Branch_1/Conv2d_0b_1x1/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_5c/Branch_1/Conv2d_0b_1x1/weights:0',
#  'InceptionV3/Mixed_5c/Branch_1/Conv_1_0c_5x5/BatchNorm/beta:0',
#  'InceptionV3/Mixed_5c/Branch_1/Conv_1_0c_5x5/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_5c/Branch_1/Conv_1_0c_5x5/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_5c/Branch_1/Conv_1_0c_5x5/weights:0',
#  'InceptionV3/Mixed_5c/Branch_2/Conv2d_0a_1x1/BatchNorm/beta:0',
#  'InceptionV3/Mixed_5c/Branch_2/Conv2d_0a_1x1/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_5c/Branch_2/Conv2d_0a_1x1/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_5c/Branch_2/Conv2d_0a_1x1/weights:0',
#  'InceptionV3/Mixed_5c/Branch_2/Conv2d_0b_3x3/BatchNorm/beta:0',
#  'InceptionV3/Mixed_5c/Branch_2/Conv2d_0b_3x3/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_5c/Branch_2/Conv2d_0b_3x3/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_5c/Branch_2/Conv2d_0b_3x3/weights:0',
#  'InceptionV3/Mixed_5c/Branch_2/Conv2d_0c_3x3/BatchNorm/beta:0',
#  'InceptionV3/Mixed_5c/Branch_2/Conv2d_0c_3x3/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_5c/Branch_2/Conv2d_0c_3x3/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_5c/Branch_2/Conv2d_0c_3x3/weights:0',
#  'InceptionV3/Mixed_5c/Branch_3/Conv2d_0b_1x1/BatchNorm/beta:0',
#  'InceptionV3/Mixed_5c/Branch_3/Conv2d_0b_1x1/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_5c/Branch_3/Conv2d_0b_1x1/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_5c/Branch_3/Conv2d_0b_1x1/weights:0',
#  'InceptionV3/Mixed_5d/Branch_0/Conv2d_0a_1x1/BatchNorm/beta:0',
#  'InceptionV3/Mixed_5d/Branch_0/Conv2d_0a_1x1/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_5d/Branch_0/Conv2d_0a_1x1/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_5d/Branch_0/Conv2d_0a_1x1/weights:0',
#  'InceptionV3/Mixed_5d/Branch_1/Conv2d_0a_1x1/BatchNorm/beta:0',
#  'InceptionV3/Mixed_5d/Branch_1/Conv2d_0a_1x1/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_5d/Branch_1/Conv2d_0a_1x1/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_5d/Branch_1/Conv2d_0a_1x1/weights:0',
#  'InceptionV3/Mixed_5d/Branch_1/Conv2d_0b_5x5/BatchNorm/beta:0',
#  'InceptionV3/Mixed_5d/Branch_1/Conv2d_0b_5x5/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_5d/Branch_1/Conv2d_0b_5x5/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_5d/Branch_1/Conv2d_0b_5x5/weights:0',
#  'InceptionV3/Mixed_5d/Branch_2/Conv2d_0a_1x1/BatchNorm/beta:0',
#  'InceptionV3/Mixed_5d/Branch_2/Conv2d_0a_1x1/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_5d/Branch_2/Conv2d_0a_1x1/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_5d/Branch_2/Conv2d_0a_1x1/weights:0',
#  'InceptionV3/Mixed_5d/Branch_2/Conv2d_0b_3x3/BatchNorm/beta:0',
#  'InceptionV3/Mixed_5d/Branch_2/Conv2d_0b_3x3/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_5d/Branch_2/Conv2d_0b_3x3/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_5d/Branch_2/Conv2d_0b_3x3/weights:0',
#  'InceptionV3/Mixed_5d/Branch_2/Conv2d_0c_3x3/BatchNorm/beta:0',
#  'InceptionV3/Mixed_5d/Branch_2/Conv2d_0c_3x3/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_5d/Branch_2/Conv2d_0c_3x3/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_5d/Branch_2/Conv2d_0c_3x3/weights:0',
#  'InceptionV3/Mixed_5d/Branch_3/Conv2d_0b_1x1/BatchNorm/beta:0',
#  'InceptionV3/Mixed_5d/Branch_3/Conv2d_0b_1x1/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_5d/Branch_3/Conv2d_0b_1x1/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_5d/Branch_3/Conv2d_0b_1x1/weights:0',
#  'InceptionV3/Mixed_6a/Branch_0/Conv2d_1a_1x1/BatchNorm/beta:0',
#  'InceptionV3/Mixed_6a/Branch_0/Conv2d_1a_1x1/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_6a/Branch_0/Conv2d_1a_1x1/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_6a/Branch_0/Conv2d_1a_1x1/weights:0',
#  'InceptionV3/Mixed_6a/Branch_1/Conv2d_0a_1x1/BatchNorm/beta:0',
#  'InceptionV3/Mixed_6a/Branch_1/Conv2d_0a_1x1/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_6a/Branch_1/Conv2d_0a_1x1/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_6a/Branch_1/Conv2d_0a_1x1/weights:0',
#  'InceptionV3/Mixed_6a/Branch_1/Conv2d_0b_3x3/BatchNorm/beta:0',
#  'InceptionV3/Mixed_6a/Branch_1/Conv2d_0b_3x3/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_6a/Branch_1/Conv2d_0b_3x3/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_6a/Branch_1/Conv2d_0b_3x3/weights:0',
#  'InceptionV3/Mixed_6a/Branch_1/Conv2d_1a_1x1/BatchNorm/beta:0',
#  'InceptionV3/Mixed_6a/Branch_1/Conv2d_1a_1x1/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_6a/Branch_1/Conv2d_1a_1x1/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_6a/Branch_1/Conv2d_1a_1x1/weights:0',
#  'InceptionV3/Mixed_6b/Branch_0/Conv2d_0a_1x1/BatchNorm/beta:0',
#  'InceptionV3/Mixed_6b/Branch_0/Conv2d_0a_1x1/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_6b/Branch_0/Conv2d_0a_1x1/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_6b/Branch_0/Conv2d_0a_1x1/weights:0',
#  'InceptionV3/Mixed_6b/Branch_1/Conv2d_0a_1x1/BatchNorm/beta:0',
#  'InceptionV3/Mixed_6b/Branch_1/Conv2d_0a_1x1/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_6b/Branch_1/Conv2d_0a_1x1/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_6b/Branch_1/Conv2d_0a_1x1/weights:0',
#  'InceptionV3/Mixed_6b/Branch_1/Conv2d_0b_1x7/BatchNorm/beta:0',
#  'InceptionV3/Mixed_6b/Branch_1/Conv2d_0b_1x7/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_6b/Branch_1/Conv2d_0b_1x7/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_6b/Branch_1/Conv2d_0b_1x7/weights:0',
#  'InceptionV3/Mixed_6b/Branch_1/Conv2d_0c_7x1/BatchNorm/beta:0',
#  'InceptionV3/Mixed_6b/Branch_1/Conv2d_0c_7x1/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_6b/Branch_1/Conv2d_0c_7x1/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_6b/Branch_1/Conv2d_0c_7x1/weights:0',
#  'InceptionV3/Mixed_6b/Branch_2/Conv2d_0a_1x1/BatchNorm/beta:0',
#  'InceptionV3/Mixed_6b/Branch_2/Conv2d_0a_1x1/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_6b/Branch_2/Conv2d_0a_1x1/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_6b/Branch_2/Conv2d_0a_1x1/weights:0',
#  'InceptionV3/Mixed_6b/Branch_2/Conv2d_0b_7x1/BatchNorm/beta:0',
#  'InceptionV3/Mixed_6b/Branch_2/Conv2d_0b_7x1/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_6b/Branch_2/Conv2d_0b_7x1/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_6b/Branch_2/Conv2d_0b_7x1/weights:0',
#  'InceptionV3/Mixed_6b/Branch_2/Conv2d_0c_1x7/BatchNorm/beta:0',
#  'InceptionV3/Mixed_6b/Branch_2/Conv2d_0c_1x7/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_6b/Branch_2/Conv2d_0c_1x7/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_6b/Branch_2/Conv2d_0c_1x7/weights:0',
#  'InceptionV3/Mixed_6b/Branch_2/Conv2d_0d_7x1/BatchNorm/beta:0',
#  'InceptionV3/Mixed_6b/Branch_2/Conv2d_0d_7x1/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_6b/Branch_2/Conv2d_0d_7x1/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_6b/Branch_2/Conv2d_0d_7x1/weights:0',
#  'InceptionV3/Mixed_6b/Branch_2/Conv2d_0e_1x7/BatchNorm/beta:0',
#  'InceptionV3/Mixed_6b/Branch_2/Conv2d_0e_1x7/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_6b/Branch_2/Conv2d_0e_1x7/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_6b/Branch_2/Conv2d_0e_1x7/weights:0',
#  'InceptionV3/Mixed_6b/Branch_3/Conv2d_0b_1x1/BatchNorm/beta:0',
#  'InceptionV3/Mixed_6b/Branch_3/Conv2d_0b_1x1/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_6b/Branch_3/Conv2d_0b_1x1/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_6b/Branch_3/Conv2d_0b_1x1/weights:0',
#  'InceptionV3/Mixed_6c/Branch_0/Conv2d_0a_1x1/BatchNorm/beta:0',
#  'InceptionV3/Mixed_6c/Branch_0/Conv2d_0a_1x1/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_6c/Branch_0/Conv2d_0a_1x1/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_6c/Branch_0/Conv2d_0a_1x1/weights:0',
#  'InceptionV3/Mixed_6c/Branch_1/Conv2d_0a_1x1/BatchNorm/beta:0',
#  'InceptionV3/Mixed_6c/Branch_1/Conv2d_0a_1x1/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_6c/Branch_1/Conv2d_0a_1x1/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_6c/Branch_1/Conv2d_0a_1x1/weights:0',
#  'InceptionV3/Mixed_6c/Branch_1/Conv2d_0b_1x7/BatchNorm/beta:0',
#  'InceptionV3/Mixed_6c/Branch_1/Conv2d_0b_1x7/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_6c/Branch_1/Conv2d_0b_1x7/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_6c/Branch_1/Conv2d_0b_1x7/weights:0',
#  'InceptionV3/Mixed_6c/Branch_1/Conv2d_0c_7x1/BatchNorm/beta:0',
#  'InceptionV3/Mixed_6c/Branch_1/Conv2d_0c_7x1/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_6c/Branch_1/Conv2d_0c_7x1/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_6c/Branch_1/Conv2d_0c_7x1/weights:0',
#  'InceptionV3/Mixed_6c/Branch_2/Conv2d_0a_1x1/BatchNorm/beta:0',
#  'InceptionV3/Mixed_6c/Branch_2/Conv2d_0a_1x1/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_6c/Branch_2/Conv2d_0a_1x1/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_6c/Branch_2/Conv2d_0a_1x1/weights:0',
#  'InceptionV3/Mixed_6c/Branch_2/Conv2d_0b_7x1/BatchNorm/beta:0',
#  'InceptionV3/Mixed_6c/Branch_2/Conv2d_0b_7x1/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_6c/Branch_2/Conv2d_0b_7x1/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_6c/Branch_2/Conv2d_0b_7x1/weights:0',
#  'InceptionV3/Mixed_6c/Branch_2/Conv2d_0c_1x7/BatchNorm/beta:0',
#  'InceptionV3/Mixed_6c/Branch_2/Conv2d_0c_1x7/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_6c/Branch_2/Conv2d_0c_1x7/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_6c/Branch_2/Conv2d_0c_1x7/weights:0',
#  'InceptionV3/Mixed_6c/Branch_2/Conv2d_0d_7x1/BatchNorm/beta:0',
#  'InceptionV3/Mixed_6c/Branch_2/Conv2d_0d_7x1/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_6c/Branch_2/Conv2d_0d_7x1/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_6c/Branch_2/Conv2d_0d_7x1/weights:0',
#  'InceptionV3/Mixed_6c/Branch_2/Conv2d_0e_1x7/BatchNorm/beta:0',
#  'InceptionV3/Mixed_6c/Branch_2/Conv2d_0e_1x7/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_6c/Branch_2/Conv2d_0e_1x7/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_6c/Branch_2/Conv2d_0e_1x7/weights:0',
#  'InceptionV3/Mixed_6c/Branch_3/Conv2d_0b_1x1/BatchNorm/beta:0',
#  'InceptionV3/Mixed_6c/Branch_3/Conv2d_0b_1x1/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_6c/Branch_3/Conv2d_0b_1x1/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_6c/Branch_3/Conv2d_0b_1x1/weights:0',
#  'InceptionV3/Mixed_6d/Branch_0/Conv2d_0a_1x1/BatchNorm/beta:0',
#  'InceptionV3/Mixed_6d/Branch_0/Conv2d_0a_1x1/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_6d/Branch_0/Conv2d_0a_1x1/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_6d/Branch_0/Conv2d_0a_1x1/weights:0',
#  'InceptionV3/Mixed_6d/Branch_1/Conv2d_0a_1x1/BatchNorm/beta:0',
#  'InceptionV3/Mixed_6d/Branch_1/Conv2d_0a_1x1/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_6d/Branch_1/Conv2d_0a_1x1/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_6d/Branch_1/Conv2d_0a_1x1/weights:0',
#  'InceptionV3/Mixed_6d/Branch_1/Conv2d_0b_1x7/BatchNorm/beta:0',
#  'InceptionV3/Mixed_6d/Branch_1/Conv2d_0b_1x7/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_6d/Branch_1/Conv2d_0b_1x7/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_6d/Branch_1/Conv2d_0b_1x7/weights:0',
#  'InceptionV3/Mixed_6d/Branch_1/Conv2d_0c_7x1/BatchNorm/beta:0',
#  'InceptionV3/Mixed_6d/Branch_1/Conv2d_0c_7x1/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_6d/Branch_1/Conv2d_0c_7x1/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_6d/Branch_1/Conv2d_0c_7x1/weights:0',
#  'InceptionV3/Mixed_6d/Branch_2/Conv2d_0a_1x1/BatchNorm/beta:0',
#  'InceptionV3/Mixed_6d/Branch_2/Conv2d_0a_1x1/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_6d/Branch_2/Conv2d_0a_1x1/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_6d/Branch_2/Conv2d_0a_1x1/weights:0',
#  'InceptionV3/Mixed_6d/Branch_2/Conv2d_0b_7x1/BatchNorm/beta:0',
#  'InceptionV3/Mixed_6d/Branch_2/Conv2d_0b_7x1/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_6d/Branch_2/Conv2d_0b_7x1/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_6d/Branch_2/Conv2d_0b_7x1/weights:0',
#  'InceptionV3/Mixed_6d/Branch_2/Conv2d_0c_1x7/BatchNorm/beta:0',
#  'InceptionV3/Mixed_6d/Branch_2/Conv2d_0c_1x7/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_6d/Branch_2/Conv2d_0c_1x7/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_6d/Branch_2/Conv2d_0c_1x7/weights:0',
#  'InceptionV3/Mixed_6d/Branch_2/Conv2d_0d_7x1/BatchNorm/beta:0',
#  'InceptionV3/Mixed_6d/Branch_2/Conv2d_0d_7x1/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_6d/Branch_2/Conv2d_0d_7x1/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_6d/Branch_2/Conv2d_0d_7x1/weights:0',
#  'InceptionV3/Mixed_6d/Branch_2/Conv2d_0e_1x7/BatchNorm/beta:0',
#  'InceptionV3/Mixed_6d/Branch_2/Conv2d_0e_1x7/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_6d/Branch_2/Conv2d_0e_1x7/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_6d/Branch_2/Conv2d_0e_1x7/weights:0',
#  'InceptionV3/Mixed_6d/Branch_3/Conv2d_0b_1x1/BatchNorm/beta:0',
#  'InceptionV3/Mixed_6d/Branch_3/Conv2d_0b_1x1/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_6d/Branch_3/Conv2d_0b_1x1/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_6d/Branch_3/Conv2d_0b_1x1/weights:0',
#  'InceptionV3/Mixed_6e/Branch_0/Conv2d_0a_1x1/BatchNorm/beta:0',
#  'InceptionV3/Mixed_6e/Branch_0/Conv2d_0a_1x1/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_6e/Branch_0/Conv2d_0a_1x1/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_6e/Branch_0/Conv2d_0a_1x1/weights:0',
#  'InceptionV3/Mixed_6e/Branch_1/Conv2d_0a_1x1/BatchNorm/beta:0',
#  'InceptionV3/Mixed_6e/Branch_1/Conv2d_0a_1x1/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_6e/Branch_1/Conv2d_0a_1x1/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_6e/Branch_1/Conv2d_0a_1x1/weights:0',
#  'InceptionV3/Mixed_6e/Branch_1/Conv2d_0b_1x7/BatchNorm/beta:0',
#  'InceptionV3/Mixed_6e/Branch_1/Conv2d_0b_1x7/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_6e/Branch_1/Conv2d_0b_1x7/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_6e/Branch_1/Conv2d_0b_1x7/weights:0',
#  'InceptionV3/Mixed_6e/Branch_1/Conv2d_0c_7x1/BatchNorm/beta:0',
#  'InceptionV3/Mixed_6e/Branch_1/Conv2d_0c_7x1/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_6e/Branch_1/Conv2d_0c_7x1/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_6e/Branch_1/Conv2d_0c_7x1/weights:0',
#  'InceptionV3/Mixed_6e/Branch_2/Conv2d_0a_1x1/BatchNorm/beta:0',
#  'InceptionV3/Mixed_6e/Branch_2/Conv2d_0a_1x1/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_6e/Branch_2/Conv2d_0a_1x1/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_6e/Branch_2/Conv2d_0a_1x1/weights:0',
#  'InceptionV3/Mixed_6e/Branch_2/Conv2d_0b_7x1/BatchNorm/beta:0',
#  'InceptionV3/Mixed_6e/Branch_2/Conv2d_0b_7x1/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_6e/Branch_2/Conv2d_0b_7x1/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_6e/Branch_2/Conv2d_0b_7x1/weights:0',
#  'InceptionV3/Mixed_6e/Branch_2/Conv2d_0c_1x7/BatchNorm/beta:0',
#  'InceptionV3/Mixed_6e/Branch_2/Conv2d_0c_1x7/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_6e/Branch_2/Conv2d_0c_1x7/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_6e/Branch_2/Conv2d_0c_1x7/weights:0',
#  'InceptionV3/Mixed_6e/Branch_2/Conv2d_0d_7x1/BatchNorm/beta:0',
#  'InceptionV3/Mixed_6e/Branch_2/Conv2d_0d_7x1/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_6e/Branch_2/Conv2d_0d_7x1/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_6e/Branch_2/Conv2d_0d_7x1/weights:0',
#  'InceptionV3/Mixed_6e/Branch_2/Conv2d_0e_1x7/BatchNorm/beta:0',
#  'InceptionV3/Mixed_6e/Branch_2/Conv2d_0e_1x7/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_6e/Branch_2/Conv2d_0e_1x7/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_6e/Branch_2/Conv2d_0e_1x7/weights:0',
#  'InceptionV3/Mixed_6e/Branch_3/Conv2d_0b_1x1/BatchNorm/beta:0',
#  'InceptionV3/Mixed_6e/Branch_3/Conv2d_0b_1x1/BatchNorm/moving_mean:0',
#  'InceptionV3/Mixed_6e/Branch_3/Conv2d_0b_1x1/BatchNorm/moving_variance:0',
#  'InceptionV3/Mixed_6e/Branch_3/Conv2d_0b_1x1/weights:0',
#  'style_params/transformer/expand/conv1/conv/StyleNorm/Conv/biases:0',
#  'style_params/transformer/expand/conv1/conv/StyleNorm/Conv/weights:0',
#  'style_params/transformer/expand/conv1/conv/StyleNorm/Conv_1/biases:0',
#  'style_params/transformer/expand/conv1/conv/StyleNorm/Conv_1/weights:0',
#  'style_params/transformer/expand/conv2/conv/StyleNorm/Conv/biases:0',
#  'style_params/transformer/expand/conv2/conv/StyleNorm/Conv/weights:0',
#  'style_params/transformer/expand/conv2/conv/StyleNorm/Conv_1/biases:0',
#  'style_params/transformer/expand/conv2/conv/StyleNorm/Conv_1/weights:0',
#  'style_params/transformer/expand/conv3/conv/StyleNorm/Conv/biases:0',
#  'style_params/transformer/expand/conv3/conv/StyleNorm/Conv/weights:0',
#  'style_params/transformer/expand/conv3/conv/StyleNorm/Conv_1/biases:0',
#  'style_params/transformer/expand/conv3/conv/StyleNorm/Conv_1/weights:0',
#  'style_params/transformer/residual/residual1/conv1/StyleNorm/Conv/biases:0',
#  'style_params/transformer/residual/residual1/conv1/StyleNorm/Conv/weights:0',
#  'style_params/transformer/residual/residual1/conv1/StyleNorm/Conv_1/biases:0',
#  'style_params/transformer/residual/residual1/conv1/StyleNorm/Conv_1/weights:0',
#  'style_params/transformer/residual/residual1/conv2/StyleNorm/Conv/biases:0',
#  'style_params/transformer/residual/residual1/conv2/StyleNorm/Conv/weights:0',
#  'style_params/transformer/residual/residual1/conv2/StyleNorm/Conv_1/biases:0',
#  'style_params/transformer/residual/residual1/conv2/StyleNorm/Conv_1/weights:0',
#  'style_params/transformer/residual/residual10/conv1/StyleNorm/Conv/biases:0',
#  'style_params/transformer/residual/residual10/conv1/StyleNorm/Conv/weights:0',
#  'style_params/transformer/residual/residual10/conv1/StyleNorm/Conv_1/biases:0',
#  'style_params/transformer/residual/residual10/conv1/StyleNorm/Conv_1/weights:0',
#  'style_params/transformer/residual/residual10/conv2/StyleNorm/Conv/biases:0',
#  'style_params/transformer/residual/residual10/conv2/StyleNorm/Conv/weights:0',
#  'style_params/transformer/residual/residual10/conv2/StyleNorm/Conv_1/biases:0',
#  'style_params/transformer/residual/residual10/conv2/StyleNorm/Conv_1/weights:0',
#  'style_params/transformer/residual/residual11/conv1/StyleNorm/Conv/biases:0',
#  'style_params/transformer/residual/residual11/conv1/StyleNorm/Conv/weights:0',
#  'style_params/transformer/residual/residual11/conv1/StyleNorm/Conv_1/biases:0',
#  'style_params/transformer/residual/residual11/conv1/StyleNorm/Conv_1/weights:0',
#  'style_params/transformer/residual/residual11/conv2/StyleNorm/Conv/biases:0',
#  'style_params/transformer/residual/residual11/conv2/StyleNorm/Conv/weights:0',
#  'style_params/transformer/residual/residual11/conv2/StyleNorm/Conv_1/biases:0',
#  'style_params/transformer/residual/residual11/conv2/StyleNorm/Conv_1/weights:0',
#  'style_params/transformer/residual/residual12/conv1/StyleNorm/Conv/biases:0',
#  'style_params/transformer/residual/residual12/conv1/StyleNorm/Conv/weights:0',
#  'style_params/transformer/residual/residual12/conv1/StyleNorm/Conv_1/biases:0',
#  'style_params/transformer/residual/residual12/conv1/StyleNorm/Conv_1/weights:0',
#  'style_params/transformer/residual/residual12/conv2/StyleNorm/Conv/biases:0',
#  'style_params/transformer/residual/residual12/conv2/StyleNorm/Conv/weights:0',
#  'style_params/transformer/residual/residual12/conv2/StyleNorm/Conv_1/biases:0',
#  'style_params/transformer/residual/residual12/conv2/StyleNorm/Conv_1/weights:0',
#  'style_params/transformer/residual/residual13/conv1/StyleNorm/Conv/biases:0',
#  'style_params/transformer/residual/residual13/conv1/StyleNorm/Conv/weights:0',
#  'style_params/transformer/residual/residual13/conv1/StyleNorm/Conv_1/biases:0',
#  'style_params/transformer/residual/residual13/conv1/StyleNorm/Conv_1/weights:0',
#  'style_params/transformer/residual/residual13/conv2/StyleNorm/Conv/biases:0',
#  'style_params/transformer/residual/residual13/conv2/StyleNorm/Conv/weights:0',
#  'style_params/transformer/residual/residual13/conv2/StyleNorm/Conv_1/biases:0',
#  'style_params/transformer/residual/residual13/conv2/StyleNorm/Conv_1/weights:0',
#  'style_params/transformer/residual/residual14/conv1/StyleNorm/Conv/biases:0',
#  'style_params/transformer/residual/residual14/conv1/StyleNorm/Conv/weights:0',
#  'style_params/transformer/residual/residual14/conv1/StyleNorm/Conv_1/biases:0',
#  'style_params/transformer/residual/residual14/conv1/StyleNorm/Conv_1/weights:0',
#  'style_params/transformer/residual/residual14/conv2/StyleNorm/Conv/biases:0',
#  'style_params/transformer/residual/residual14/conv2/StyleNorm/Conv/weights:0',
#  'style_params/transformer/residual/residual14/conv2/StyleNorm/Conv_1/biases:0',
#  'style_params/transformer/residual/residual14/conv2/StyleNorm/Conv_1/weights:0',
#  'style_params/transformer/residual/residual15/conv1/StyleNorm/Conv/biases:0',
#  'style_params/transformer/residual/residual15/conv1/StyleNorm/Conv/weights:0',
#  'style_params/transformer/residual/residual15/conv1/StyleNorm/Conv_1/biases:0',
#  'style_params/transformer/residual/residual15/conv1/StyleNorm/Conv_1/weights:0',
#  'style_params/transformer/residual/residual15/conv2/StyleNorm/Conv/biases:0',
#  'style_params/transformer/residual/residual15/conv2/StyleNorm/Conv/weights:0',
#  'style_params/transformer/residual/residual15/conv2/StyleNorm/Conv_1/biases:0',
#  'style_params/transformer/residual/residual15/conv2/StyleNorm/Conv_1/weights:0',
#  'style_params/transformer/residual/residual16/conv1/StyleNorm/Conv/biases:0',
#  'style_params/transformer/residual/residual16/conv1/StyleNorm/Conv/weights:0',
#  'style_params/transformer/residual/residual16/conv1/StyleNorm/Conv_1/biases:0',
#  'style_params/transformer/residual/residual16/conv1/StyleNorm/Conv_1/weights:0',
#  'style_params/transformer/residual/residual16/conv2/StyleNorm/Conv/biases:0',
#  'style_params/transformer/residual/residual16/conv2/StyleNorm/Conv/weights:0',
#  'style_params/transformer/residual/residual16/conv2/StyleNorm/Conv_1/biases:0',
#  'style_params/transformer/residual/residual16/conv2/StyleNorm/Conv_1/weights:0',
#  'style_params/transformer/residual/residual17/conv1/StyleNorm/Conv/biases:0',
#  'style_params/transformer/residual/residual17/conv1/StyleNorm/Conv/weights:0',
#  'style_params/transformer/residual/residual17/conv1/StyleNorm/Conv_1/biases:0',
#  'style_params/transformer/residual/residual17/conv1/StyleNorm/Conv_1/weights:0',
#  'style_params/transformer/residual/residual17/conv2/StyleNorm/Conv/biases:0',
#  'style_params/transformer/residual/residual17/conv2/StyleNorm/Conv/weights:0',
#  'style_params/transformer/residual/residual17/conv2/StyleNorm/Conv_1/biases:0',
#  'style_params/transformer/residual/residual17/conv2/StyleNorm/Conv_1/weights:0',
#  'style_params/transformer/residual/residual18/conv1/StyleNorm/Conv/biases:0',
#  'style_params/transformer/residual/residual18/conv1/StyleNorm/Conv/weights:0',
#  'style_params/transformer/residual/residual18/conv1/StyleNorm/Conv_1/biases:0',
#  'style_params/transformer/residual/residual18/conv1/StyleNorm/Conv_1/weights:0',
#  'style_params/transformer/residual/residual18/conv2/StyleNorm/Conv/biases:0',
#  'style_params/transformer/residual/residual18/conv2/StyleNorm/Conv/weights:0',
#  'style_params/transformer/residual/residual18/conv2/StyleNorm/Conv_1/biases:0',
#  'style_params/transformer/residual/residual18/conv2/StyleNorm/Conv_1/weights:0',
#  'style_params/transformer/residual/residual19/conv1/StyleNorm/Conv/biases:0',
#  'style_params/transformer/residual/residual19/conv1/StyleNorm/Conv/weights:0',
#  'style_params/transformer/residual/residual19/conv1/StyleNorm/Conv_1/biases:0',
#  'style_params/transformer/residual/residual19/conv1/StyleNorm/Conv_1/weights:0',
#  'style_params/transformer/residual/residual19/conv2/StyleNorm/Conv/biases:0',
#  'style_params/transformer/residual/residual19/conv2/StyleNorm/Conv/weights:0',
#  'style_params/transformer/residual/residual19/conv2/StyleNorm/Conv_1/biases:0',
#  'style_params/transformer/residual/residual19/conv2/StyleNorm/Conv_1/weights:0',
#  'style_params/transformer/residual/residual2/conv1/StyleNorm/Conv/biases:0',
#  'style_params/transformer/residual/residual2/conv1/StyleNorm/Conv/weights:0',
#  'style_params/transformer/residual/residual2/conv1/StyleNorm/Conv_1/biases:0',
#  'style_params/transformer/residual/residual2/conv1/StyleNorm/Conv_1/weights:0',
#  'style_params/transformer/residual/residual2/conv2/StyleNorm/Conv/biases:0',
#  'style_params/transformer/residual/residual2/conv2/StyleNorm/Conv/weights:0',
#  'style_params/transformer/residual/residual2/conv2/StyleNorm/Conv_1/biases:0',
#  'style_params/transformer/residual/residual2/conv2/StyleNorm/Conv_1/weights:0',
#  'style_params/transformer/residual/residual20/conv1/StyleNorm/Conv/biases:0',
#  'style_params/transformer/residual/residual20/conv1/StyleNorm/Conv/weights:0',
#  'style_params/transformer/residual/residual20/conv1/StyleNorm/Conv_1/biases:0',
#  'style_params/transformer/residual/residual20/conv1/StyleNorm/Conv_1/weights:0',
#  'style_params/transformer/residual/residual20/conv2/StyleNorm/Conv/biases:0',
#  'style_params/transformer/residual/residual20/conv2/StyleNorm/Conv/weights:0',
#  'style_params/transformer/residual/residual20/conv2/StyleNorm/Conv_1/biases:0',
#  'style_params/transformer/residual/residual20/conv2/StyleNorm/Conv_1/weights:0',
#  'style_params/transformer/residual/residual3/conv1/StyleNorm/Conv/biases:0',
#  'style_params/transformer/residual/residual3/conv1/StyleNorm/Conv/weights:0',
#  'style_params/transformer/residual/residual3/conv1/StyleNorm/Conv_1/biases:0',
#  'style_params/transformer/residual/residual3/conv1/StyleNorm/Conv_1/weights:0',
#  'style_params/transformer/residual/residual3/conv2/StyleNorm/Conv/biases:0',
#  'style_params/transformer/residual/residual3/conv2/StyleNorm/Conv/weights:0',
#  'style_params/transformer/residual/residual3/conv2/StyleNorm/Conv_1/biases:0',
#  'style_params/transformer/residual/residual3/conv2/StyleNorm/Conv_1/weights:0',
#  'style_params/transformer/residual/residual4/conv1/StyleNorm/Conv/biases:0',
#  'style_params/transformer/residual/residual4/conv1/StyleNorm/Conv/weights:0',
#  'style_params/transformer/residual/residual4/conv1/StyleNorm/Conv_1/biases:0',
#  'style_params/transformer/residual/residual4/conv1/StyleNorm/Conv_1/weights:0',
#  'style_params/transformer/residual/residual4/conv2/StyleNorm/Conv/biases:0',
#  'style_params/transformer/residual/residual4/conv2/StyleNorm/Conv/weights:0',
#  'style_params/transformer/residual/residual4/conv2/StyleNorm/Conv_1/biases:0',
#  'style_params/transformer/residual/residual4/conv2/StyleNorm/Conv_1/weights:0',
#  'style_params/transformer/residual/residual5/conv1/StyleNorm/Conv/biases:0',
#  'style_params/transformer/residual/residual5/conv1/StyleNorm/Conv/weights:0',
#  'style_params/transformer/residual/residual5/conv1/StyleNorm/Conv_1/biases:0',
#  'style_params/transformer/residual/residual5/conv1/StyleNorm/Conv_1/weights:0',
#  'style_params/transformer/residual/residual5/conv2/StyleNorm/Conv/biases:0',
#  'style_params/transformer/residual/residual5/conv2/StyleNorm/Conv/weights:0',
#  'style_params/transformer/residual/residual5/conv2/StyleNorm/Conv_1/biases:0',
#  'style_params/transformer/residual/residual5/conv2/StyleNorm/Conv_1/weights:0',
#  'style_params/transformer/residual/residual6/conv1/StyleNorm/Conv/biases:0',
#  'style_params/transformer/residual/residual6/conv1/StyleNorm/Conv/weights:0',
#  'style_params/transformer/residual/residual6/conv1/StyleNorm/Conv_1/biases:0',
#  'style_params/transformer/residual/residual6/conv1/StyleNorm/Conv_1/weights:0',
#  'style_params/transformer/residual/residual6/conv2/StyleNorm/Conv/biases:0',
#  'style_params/transformer/residual/residual6/conv2/StyleNorm/Conv/weights:0',
#  'style_params/transformer/residual/residual6/conv2/StyleNorm/Conv_1/biases:0',
#  'style_params/transformer/residual/residual6/conv2/StyleNorm/Conv_1/weights:0',
#  'style_params/transformer/residual/residual7/conv1/StyleNorm/Conv/biases:0',
#  'style_params/transformer/residual/residual7/conv1/StyleNorm/Conv/weights:0',
#  'style_params/transformer/residual/residual7/conv1/StyleNorm/Conv_1/biases:0',
#  'style_params/transformer/residual/residual7/conv1/StyleNorm/Conv_1/weights:0',
#  'style_params/transformer/residual/residual7/conv2/StyleNorm/Conv/biases:0',
#  'style_params/transformer/residual/residual7/conv2/StyleNorm/Conv/weights:0',
#  'style_params/transformer/residual/residual7/conv2/StyleNorm/Conv_1/biases:0',
#  'style_params/transformer/residual/residual7/conv2/StyleNorm/Conv_1/weights:0',
#  'style_params/transformer/residual/residual8/conv1/StyleNorm/Conv/biases:0',
#  'style_params/transformer/residual/residual8/conv1/StyleNorm/Conv/weights:0',
#  'style_params/transformer/residual/residual8/conv1/StyleNorm/Conv_1/biases:0',
#  'style_params/transformer/residual/residual8/conv1/StyleNorm/Conv_1/weights:0',
#  'style_params/transformer/residual/residual8/conv2/StyleNorm/Conv/biases:0',
#  'style_params/transformer/residual/residual8/conv2/StyleNorm/Conv/weights:0',
#  'style_params/transformer/residual/residual8/conv2/StyleNorm/Conv_1/biases:0',
#  'style_params/transformer/residual/residual8/conv2/StyleNorm/Conv_1/weights:0',
#  'style_params/transformer/residual/residual9/conv1/StyleNorm/Conv/biases:0',
#  'style_params/transformer/residual/residual9/conv1/StyleNorm/Conv/weights:0',
#  'style_params/transformer/residual/residual9/conv1/StyleNorm/Conv_1/biases:0',
#  'style_params/transformer/residual/residual9/conv1/StyleNorm/Conv_1/weights:0',
#  'style_params/transformer/residual/residual9/conv2/StyleNorm/Conv/biases:0',
#  'style_params/transformer/residual/residual9/conv2/StyleNorm/Conv/weights:0',
#  'style_params/transformer/residual/residual9/conv2/StyleNorm/Conv_1/biases:0',
#  'style_params/transformer/residual/residual9/conv2/StyleNorm/Conv_1/weights:0',
#  'transformer/contract/conv1/BatchNorm/beta:0',
#  'transformer/contract/conv1/BatchNorm/moving_mean:0',
#  'transformer/contract/conv1/BatchNorm/moving_variance:0',
#  'transformer/contract/conv1/weights:0',
#  'transformer/contract/conv2/BatchNorm/beta:0',
#  'transformer/contract/conv2/BatchNorm/moving_mean:0',
#  'transformer/contract/conv2/BatchNorm/moving_variance:0',
#  'transformer/contract/conv2/weights:0',
#  'transformer/contract/conv3/BatchNorm/beta:0',
#  'transformer/contract/conv3/BatchNorm/moving_mean:0',
#  'transformer/contract/conv3/BatchNorm/moving_variance:0',
#  'transformer/contract/conv3/weights:0',
#  'transformer/expand/conv1/conv/weights:0',
#  'transformer/expand/conv2/conv/weights:0',
#  'transformer/expand/conv3/conv/weights:0',
#  'transformer/residual/residual1/conv1/weights:0',
#  'transformer/residual/residual1/conv2/weights:0',
#  'transformer/residual/residual10/conv1/weights:0',
#  'transformer/residual/residual10/conv2/weights:0',
#  'transformer/residual/residual11/conv1/weights:0',
#  'transformer/residual/residual11/conv2/weights:0',
#  'transformer/residual/residual12/conv1/weights:0',
#  'transformer/residual/residual12/conv2/weights:0',
#  'transformer/residual/residual13/conv1/weights:0',
#  'transformer/residual/residual13/conv2/weights:0',
#  'transformer/residual/residual14/conv1/weights:0',
#  'transformer/residual/residual14/conv2/weights:0',
#  'transformer/residual/residual15/conv1/weights:0',
#  'transformer/residual/residual15/conv2/weights:0',
#  'transformer/residual/residual16/conv1/weights:0',
#  'transformer/residual/residual16/conv2/weights:0',
#  'transformer/residual/residual17/conv1/weights:0',
#  'transformer/residual/residual17/conv2/weights:0',
#  'transformer/residual/residual18/conv1/weights:0',
#  'transformer/residual/residual18/conv2/weights:0',
#  'transformer/residual/residual19/conv1/weights:0',
#  'transformer/residual/residual19/conv2/weights:0',
#  'transformer/residual/residual2/conv1/weights:0',
#  'transformer/residual/residual2/conv2/weights:0',
#  'transformer/residual/residual20/conv1/weights:0',
#  'transformer/residual/residual20/conv2/weights:0',
#  'transformer/residual/residual3/conv1/weights:0',
#  'transformer/residual/residual3/conv2/weights:0',
#  'transformer/residual/residual4/conv1/weights:0',
#  'transformer/residual/residual4/conv2/weights:0',
#  'transformer/residual/residual5/conv1/weights:0',
#  'transformer/residual/residual5/conv2/weights:0',
#  'transformer/residual/residual6/conv1/weights:0',
#  'transformer/residual/residual6/conv2/weights:0',
#  'transformer/residual/residual7/conv1/weights:0',
#  'transformer/residual/residual7/conv2/weights:0',
#  'transformer/residual/residual8/conv1/weights:0',
#  'transformer/residual/residual8/conv2/weights:0',
#  'transformer/residual/residual9/conv1/weights:0',
#  'transformer/residual/residual9/conv2/weights:0']

# %% [markdown]
# ## Deep Dream
#
# This refers to the process of amplifying the "eye of the CNN". In other words, making the network hallucinate visual features (e.g. eyes, faces) it learnt from millions of images in plain images, where only hints of these structures exist.
#
# This is a good example of using Gradient Ascent. It's an inverse optimization problem, where instead of trying to minimize the loss - we try to maximize it, amplify it.
#
# This tutorial is based on: https://www.tensorflow.org/beta/tutorials/generative/deepdream
#
# Let's see what the network finds in a Kandinsky:

# %%
url = 'https://storage.googleapis.com/download.tensorflow.org/example_images/Vassily_Kandinsky%2C_1913_-_Composition_7.jpg'

# %%
content_image = load_image(url, image_size=(375,375))
show_n([content_image])
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/example_images/Vassily_Kandinsky%2C_1913_-_Composition_7.jpg
# 196608/195196 [==============================] - 0s 0us/step

# %% [markdown]
# Here we use the Inception network from Google. It was a winner of the ILSVRC circa 2013.
#
# Read about it here if interested in knowing more: https://medium.com/coinmonks/paper-review-of-googlenet-inception-v1-winner-of-ilsvlc-2014-image-classification-c2b3565a64e7

# %%
base_model = tf.keras.applications.InceptionV3(include_top=False, weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 0s 0us/step

# %% [markdown]
# We select a couple of layers from the network to maximize. These layers correspond to a size/level of visual construct. The lower layers will see very local visual features (lines, little blobs), while the higher ones will see e.g. eyes, faces, noses, etc.

# %%
# Maximize the activations of these layers
names = ['mixed3', 'mixed5']
layers = [base_model.get_layer(name).output for name in names]

# Create the feature extraction model
dream_model = tf.keras.Model(inputs=base_model.input, outputs=layers)

# %% [markdown]
# The Loss function guides our inverse optimization. Here it is very simple, it's just looking to increase the activation in our selected layers. You can explore the activations of InceptionNet here: https://distill.pub/2019/activation-atlas/ See every layer and neuron group "like" a different concept like: Pineapple, Hot dog, Jeans and Sleeping bag...

# %%
def calc_loss(img, model):
    # Pass forward the image through the model to retrieve the activations.
    layer_activations = model(img)

    losses = []
    for act in layer_activations:
        loss = tf.math.reduce_mean(act)
        losses.append(loss)

    return  tf.reduce_sum(losses)

# %% [markdown]
# Some code is obviously necessary to run the optimization... I'll spare you the details, but if you want to run this for youself you'd need to execute these cells.

# %%
@tf.function
def deepdream(model, img, step_size):
    print("deepdream",type(img),img.shape)
    with tf.GradientTape() as tape:
        # This needs gradients relative to `img`
        # `GradientTape` only watches `tf.Variable`s by default
        tape.watch(img)
        loss = calc_loss(img, model)

    # Calculate the gradient of the loss with respect to the pixels of the input image.
    gradients = tape.gradient(loss, img)

    # Normalize the gradients.
    gradients /= tf.math.reduce_std(gradients) + 1e-8 
    
    # In gradient ascent, the "loss" is maximized so that the input image increasingly "excites" the layers.
    # You can update the image by directly adding the gradients (because they're the same shape!)
    img = img + gradients*step_size
    img = tf.clip_by_value(img, -1, 1)

    return loss, img

# %%
def deprocess(img):
    img = 127.5*(img + 1.0)
    return tf.cast(img, tf.uint8)

# %%
def run_deep_dream_simple(model, img, steps=100, step_size=0.01):
    # Convert from uint8 to the range expected by the model.
    clear_output(wait=True)
    show_n([deprocess(img)])

    # main execution loop, every iteration applies little changes to the image
    for step in range(steps):
        loss, img = deepdream(model, img, step_size)

        if step % 100 == 0:
            clear_output(wait=True)
            show_n([deprocess(img)])
            print ("Step {}, loss {}".format(step, loss))

    clear_output(wait=True)
    show_n([deprocess(img)])

    return img

# %%
content_image_i3 = np.array(content_image) * 1.999 - 1.0

# %%
dream_img = run_deep_dream_simple(model=dream_model, img=content_image_i3, steps=800, step_size=0.001)

# %% [markdown]
# Above, we only get these little changes applied at a single "scale". Meaning, the visual constructs (think "eyes") are of a single scale, for example 20x20 pixels. We would like to get "eyes" in any scale, even much bigger.
#
# The following loop will change the scale of the image itself (a.k.a octave) and apply the same algorithm as above.
#
# The result is "smoother" and find bigger things. For example I can definitely see a "bird" and a few "dogs".

# %%
OCTAVE_SCALE = 1.3

img = tf.constant(np.array(content_image_i3))
base_shape = tf.cast(tf.shape(img)[1:-1], tf.float32)
print(base_shape)

for n in range(3):
    new_shape = tf.cast(base_shape*(OCTAVE_SCALE**n), tf.int32)

    img = tf.image.resize(img, new_shape).numpy()

    img = run_deep_dream_simple(model=dream_model, img=img, steps=200, step_size=0.001)

# %% [markdown]
# To get an even more hi-res result we utilize Tiling. We split the image to tiles and run the algorithm on each small tile at higher resolution.
#
# The end result is much higer resolution and shows the "puppy slug" effect you must have seen before.
#
# Again below are some extra code cells you'd need to run. Expand them out for details.

# %%
def random_roll(img, maxroll):
    # Randomly shift the image to avoid tiled boundaries.
    shift = tf.random.uniform(shape=[2], minval=-maxroll, maxval=maxroll, dtype=tf.int32)
    shift_down, shift_right = shift[0],shift[1] 
    img_rolled = tf.roll(tf.roll(img, shift_right, axis=1), shift_down, axis=0)
    return shift_down, shift_right, img_rolled

# %%
@tf.function
def get_tiled_gradients(model, img, tile_size=512):
    shift_down, shift_right, img_rolled = random_roll(img, tile_size)

    # Initialize the image gradients to zero.
    gradients = tf.zeros_like(img_rolled)

    for x in tf.range(0, img_rolled.shape[0], tile_size):
        for y in tf.range(0, img_rolled.shape[1], tile_size):
            # Calculate the gradients for this tile.
            with tf.GradientTape() as tape:
                # This needs gradients relative to `img_rolled`.
                # `GradientTape` only watches `tf.Variable`s by default.
                tape.watch(img_rolled)

                # Extract a tile out of the image.
                img_tile = img_rolled[x:x+tile_size, y:y+tile_size]
                loss = calc_loss(img_tile, model)

                # Update the image gradients for this tile.
                gradients = gradients + tape.gradient(loss, img_rolled)

    # Undo the random shift applied to the image and its gradients.
    gradients = tf.roll(tf.roll(gradients, -shift_right, axis=1), -shift_down, axis=0)

    # Normalize the gradients.
    gradients /= tf.math.reduce_std(gradients) + 1e-8 

    return gradients

# %%
def run_deep_dream_with_octaves(model, img, steps_per_octave=100, step_size=0.01, 
                                num_octaves=3, octave_scale=1.3):
    for octave in range(num_octaves):
        # Scale the image based on the octave
        if octave>0:
            new_size = tf.cast(img.shape[1:3], tf.float32)*octave_scale
            img = tf.image.resize(img, tf.cast(new_size, tf.int32))

        for step in range(steps_per_octave):
            gradients = get_tiled_gradients(model, img)
            img = img + gradients*step_size
            img = tf.clip_by_value(img, -1, 1)

            if step % 10 == 0:
                clear_output(wait=True)
                show_n([deprocess(img)])
                print ("Octave {}, Step {}".format(octave, step))

    clear_output(wait=True)
    result = deprocess(img)
    show_n([result])

    return result

# %%
dream_img = run_deep_dream_with_octaves(model=dream_model, img=content_image_i3, step_size=0.01)

# %% [markdown]
# ## Neural Doodle
#
# Neural doodle is effectively guided style transfer. First we mask the input style image with regions of different "semantic" value, e.g. Grass, Sky, Rock, etc. Then given a new mask we ask the model to complete in the details from the original image.
#
# As per usual, there's going to be some significant code to make this happen. Feel free to explore it.

# %%
def gram_matrix(input_tensor):
    result = tf.linalg.einsum('bijc,bijd->bcd', input_tensor, input_tensor)
    input_shape = tf.shape(input_tensor)
    num_locations = tf.cast(input_shape[1]*input_shape[2], tf.float32)
    return result/(num_locations)

# %% [markdown]
# Like we did before, we select some specific layers (this time from [VGG19](https://arxiv.org/abs/1409.1556)) to guide the transfer. See for "Style" we pick layers from multiple heights, so we get small scale features as well as larger ones:

# %%
content_layers = ['block5_conv2'] # content layer
style_layers = ['block%d_conv1'%i for i in [1,2,3,4]] # Style layer of interest

# %%
class StyleContentModel(tf.keras.models.Model):
    def __init__(self, style_layers, content_layers, input_shape):
        super(StyleContentModel, self).__init__()
        self.content_layers = content_layers
        self.style_layers = style_layers
        self.num_style_layers = len(self.style_layers)
        
        # Load our model. Load pretrained VGG, trained on imagenet data
        self.vgg = tf.keras.applications.VGG19(include_top=False, weights='imagenet')
        self.vgg.trainable = False

        # mask model as a series of pooling
        mask_input = tf.keras.layers.Input(shape=input_shape, name='mask_input')
        x = mask_input
        for layer in self.vgg.layers[1:]:
            name = 'mask_%s' % layer.name
            if 'conv' in layer.name:
                x = tf.keras.layers.AveragePooling2D((3, 3), padding='same', strides=(1, 1), name=name)(x)
            elif 'pool' in layer.name:
                x = tf.keras.layers.AveragePooling2D((2, 2), name=name)(x)
        self.mask_model = tf.keras.Model(mask_input, x)
        self.vgg_layers_mask = tf.keras.Model([self.mask_model.input], 
                                              [self.mask_model.get_layer('mask_%s' % name).output for name in self.style_layers])

        self.vgg_layers_style   = tf.keras.Model([self.vgg.input], 
                                                 [self.vgg.get_layer(name).output for name in self.style_layers])
        self.vgg_layers_content = tf.keras.Model([self.vgg.input], 
                                                 [self.vgg.get_layer(name).output for name in self.content_layers])
        

    def call(self, inputs, masks, show_masks=False):
        "Expects float input in [0,1]"
        inputs = inputs * 255.0
        style_outputs = []
        mask_features = [self.vgg_layers_mask(tf.cast(tf.reshape(m, [1,*m.shape,1]), tf.float32)) for m in masks]
        if show_masks:
            show_n([tf.squeeze(m,-1) for m in mask_features[0]], colorbar=True)
        
        preprocessed_input = tf.keras.applications.vgg19.preprocess_input(inputs) 
        for m in mask_features:
            outputs_style = self.vgg_layers_style(preprocessed_input)
            outputs_style = [outputs_style[i] * m[i] for i in range(len(m))] # apply mask to image features
            outputs_style = [gram_matrix(outputs_style[i]) / tf.reduce_mean(m[i]) for i in range(len(m))]
            style_dict = {style_name:value for style_name, value in zip(self.style_layers, outputs_style)}
            style_outputs += [style_dict]
            
        content_outputs = self.vgg_layers_content(preprocessed_input)
        if not isinstance(content_outputs, list):
            content_outputs = [content_outputs]
        content_dict = {content_name:value for content_name, value in zip(self.content_layers, content_outputs)}

        return {'content':content_dict, 'style':style_outputs}

# %%
def kmeans(xs, k):
    assert xs.ndim == 2
    try:
        from sklearn.cluster import k_means
        _, labels, _ = k_means(xs.astype('float64'), k)
    except ImportError:
        from scipy.cluster.vq import kmeans2
        _, labels = kmeans2(xs, k, missing='raise')
    return labels

def load_mask_labels(style_mask_path, target_mask_path, num_labels, show_masks=False):
    '''Load both target and style masks.
    A mask image (nr x nc) with m labels/colors will be loaded as an array
    '''
    target_mask_img = load_image(target_mask_path)
    style_mask_img = load_image(style_mask_path)
    if show_masks:
        show_n([style_mask_img, target_mask_img], ['Input mask', 'Target mask'])
        
    mask_vecs = np.vstack([tf.reshape(style_mask_img, (-1, 3)), tf.reshape(target_mask_img, (-1, 3))])

    img_nrows, img_ncols = style_mask_img.shape[1:3]
    labels = kmeans(mask_vecs, num_labels)
    style_mask_label = labels[:img_nrows * img_ncols].reshape((img_nrows, img_ncols))
    target_mask_label = labels[img_nrows * img_ncols:].reshape((img_nrows, img_ncols))

    return ([style_mask_label == r for r in range(num_labels)], 
            [target_mask_label == r for r in range(num_labels)])

# %% [markdown]
# Consider this Max Liebermann painting.

# %%
content_image = load_image("https://upload.wikimedia.org/wikipedia/commons/thumb/a/af/Max_Liebermann_Der_Nutzgarten_in_Wannsee_nach_Westen_1922.jpg/512px-Max_Liebermann_Der_Nutzgarten_in_Wannsee_nach_Westen_1922.jpg")
show_n([content_image],['Input'])

# %% [markdown]
# We can create a masking of the painting with several regions. And then doodle another mask:

# %%
style_masks, target_masks = load_mask_labels("https://github.com/mitmedialab/MAS.S60.Fall2020/raw/master/homework/source_mask.png", 
                                             "https://github.com/mitmedialab/MAS.S60.Fall2020/raw/master/homework/target_mask4.png", 
                                             num_labels=4, show_masks=True)
# Out:
# Downloading data from https://github.com/mitmedialab/MAS.S60.Fall2020/raw/master/homework/target_mask4.png
# 16384/8397 [==========================================================] - 0s 0us/step

# %%
model = StyleContentModel(style_layers, content_layers, [*target_masks[0].shape, 1])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 1s 0us/step

# %% [markdown]
# This shows us the way the visual features are going to be masked according the regions:

# %%
sources = model(content_image, style_masks, show_masks=True)

# %%
source_content, source_style = sources['content'], sources['style']

num_style_layers = float(len(style_layers))
num_content_layers = float(len(content_layers))

style_weight=1.
content_weight=0.1
tv_weight=100.

# %% [markdown]
# The Loss Function reveals that we are simply looking at the mean of squared distance (MSD) between our target and source image features:

# %%
def style_content_loss(outputs):
    style_outputs = outputs['style']
    content_outputs = outputs['content']
    
    loss = 0
    for i in range(len(style_outputs)):
        style_loss = tf.add_n([tf.reduce_mean((style_outputs[i][name]-source_style[i][name])**2) 
                               for name in style_outputs[i].keys()])
        loss += style_loss * style_weight / num_style_layers

    content_loss = tf.add_n([tf.reduce_mean((content_outputs[name]-source_content[name])**2) 
                     for name in content_outputs.keys()])
    
    return loss + content_loss * content_weight / num_content_layers

# %%
def clip_0_1(image):
    return tf.clip_by_value(image, clip_value_min=0.0, clip_value_max=1.0)

# %%
opt = tf.keras.optimizers.Adam(learning_rate=0.02, beta_1=0.99, epsilon=1e-1)

# %%
@tf.function()
def train_step(image, masks):
    with tf.GradientTape() as tape:
        outputs = model(image, masks)
        loss = style_content_loss(outputs) + tv_weight * tf.image.total_variation(image)

    grad = tape.gradient(loss, image)
    opt.apply_gradients([(grad, image)])
    image.assign(clip_0_1(image))

# %% [markdown]
# Below we set the input to the algorithm.
#
# Experiment with starting with a totally random image vs. starting from the original image. (Uncomment one line or the other)

# %%
# image = tf.Variable(tf.random.uniform([1, *target_masks[0].shape, 3]))
image = tf.Variable(tf.identity(content_image))

# %% [markdown]
# The execution loop simply applies the gradients imposed by the loss function:

# %%
start = time.time()

epochs = 10
steps_per_epoch = 100

clear_output(wait=True)
show_n([image.read_value()],["Train step: {}".format(0)])

step = 0
for n in range(epochs):
    for m in range(steps_per_epoch):
        step += 1
        train_step(image, target_masks)
        print(".", end='')
    clear_output(wait=True)
    show_n([image.read_value()],["Train step: {}".format(step)])

end = time.time()
print("Total time: {:.1f}".format(end-start))
# Out:
# ..........................................................
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-d9e268d5fc6a> in <module>()
#      11     for m in range(steps_per_epoch):
#      12         step += 1
# ---> 13         train_step(image, target_masks)
#      14         print(".", end='')
#      15     clear_output(wait=True)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     805       # In this case we have created variables on the first call, so we run the
#     806       # defunned version which is guaranteed to never create variables.
# --> 807       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     808     elif self._stateful_fn is not None:
#     809       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1846                            resource_variable_ops.BaseResourceVariable))],
#    1847         captured_inputs=self.captured_inputs,
# -> 1848         cancellation_manager=cancellation_manager)
#    1849
#    1850   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1922       # No tape is watching; skip to running the function.
#    1923       return self._build_call_outputs(self._inference_function.call(
# -> 1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#    1926         args,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     548               inputs=args,
#     549               attrs=attrs,
# --> 550               ctx=ctx)
#     551         else:
#     552           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# The results can be quite artistic! Although it's no Liebermann.. 😀
#
# You should try your own doodles! Just change the doodle input image.
